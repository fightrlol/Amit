# %%
class ParentA:
    def action(self):
        print("i am in A")

class ChildB(ParentA):
    pass

class ParentC:
    def action(self):
        print("i am in C")

class FinalClass(ChildB, ParentC):
    pass

obj = FinalClass()
obj.action()
# Out:
# i am in A
