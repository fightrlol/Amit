# %%
x="lemonade"
list(x)
# Out:
# ['l', 'e', 'm', 'o', 'n', 'a', 'd', 'e']

# %%
list_1 = [1,2,3,4,"Depi","learning",True,[1,2,3,"true",['ml','dl''ds']]]

# %%
type(list_1)
list_1[7][1]
# Out:
# 2

# %%
list_1.pop()
print(list_1)
# Out:
# [1, 2, 3, 4, 'Depi', 'learning', True]

# %%
x= list_1.pop()
print("popped element = ",x)
print("final list = ",list_1)
# Out:
# popped element =  True
# final list =  [1, 2, 3, 4, 'Depi', 'learning']

# %%
len(list_1)
# Out:
# 6

# %%
input_list = ["amit", "learning", "python", "machine learning", "data science", "deep learning"]
item = input("Enter the item: ")
input_list.remove(item)
input_list
# Out:
# ['learning', 'python', 'machine learning', 'data science', 'deep learning']

# %%
a = float(input("Enter first number: "))
b = float(input("Enter second number: "))
print("Addition = ",a + b)
print("Subtraction = ",a - b)
print("Multiplication = ",a * b)
print("Division = ",a / b)
# Out:
# Addition =  6.0
# Subtraction =  0.0
# Multiplication =  9.0
# Division =  1.0

# %%
score = int(input("Enter the student's score: "))
if 90 <= score <= 100:
    grade = 'A'
elif 80 <= score < 90:
    grade = 'B'
elif 70 <= score < 80:
    grade = 'C'
elif 60 <= score < 70:
    grade = 'D'
elif 0 <= score < 60:
    grade = 'F'
else:
    grade = "Invalid Score"

print(f"The student's grade is: {grade}")
# Out:
# The student's grade is: B
